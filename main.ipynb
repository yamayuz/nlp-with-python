# %%
import nltk

# %%
nltk.download()

# %%
from nltk.book import *

# %%
ex1 = ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail']

# %%
new_ex1 = sorted(ex1)
print(f'sorted: {new_ex1}')
print(f'length: {len(new_ex1)}')
# Out:
# sorted: ['Grail', 'Holy', 'Monty', 'Python', 'and', 'the']
# length: 6

# %%
print(sent4)
print(sent1)
print(sent4 + sent1)
# Out:
# ['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', 'and', 'of', 'the', 'House', 'of', 'Representatives', ':']
# ['Call', 'me', 'Ishmael', '.']
# ['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', 'and', 'of', 'the', 'House', 'of', 'Representatives', ':', 'Call', 'me', 'Ishmael', '.']

# %%
ex1.index('Python')
# Out:
# 1

# %%
ex1[1:3] = ['test']

# %%
print(ex1)
# Out:
# ['Monty', 'test', 'the', 'Holy', 'Grail']

# %%
fdist1 = FreqDist(text1)

# %%
fdist1.plot(50, cumulative=True)
